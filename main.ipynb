# %%
import plots
import pandas as pd
df = pd.read_json("deviation.json")
plot = plots.ModelPlot()
plot.draw_plots(df)
# Out:
# {'mean_plot': '.\\plots\\mean_plot.png',
#  'max_plot': '.\\plots\\max_plot.png',
#  'histogram_plot': '.\\plots\\histogram.png',
#  'box_plot': '.\\plots\\boxplots.png',
#  'scatter_plot': '.\\plots\\scatter.png',
#  'heatmap_plot': '.\\plots\\heatmap.png'}
